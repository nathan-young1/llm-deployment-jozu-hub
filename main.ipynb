# %% [markdown]
# #### Install Homebrew (for Linux / MacOs unix)

# %%
# Run this cell
# !/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"

# Note: You can also run in the terminal but without the preceeding !
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# Out:
# ==> Running in non-interactive mode because `$NONINTERACTIVE` is set.
# /usr/bin/ldd: line 41: printf: write error: Broken pipe
# /usr/bin/ldd: line 43: printf: write error: Broken pipe
# ==> Checking for `sudo` access (which may request your password)...
# ==> This script will install:
# /home/linuxbrew/.linuxbrew/bin/brew
# /home/linuxbrew/.linuxbrew/share/doc/homebrew
# /home/linuxbrew/.linuxbrew/share/man/man1/brew.1
# /home/linuxbrew/.linuxbrew/share/zsh/site-functions/_brew
# /home/linuxbrew/.linuxbrew/etc/bash_completion.d/brew
# /home/linuxbrew/.linuxbrew/Homebrew
# ==> /usr/bin/sudo /bin/chown -R jonathan-5gy7d:jonathan-5gy7d /home/linuxbrew/.linuxbrew/Homebrew
# ==> Found Git: /commands/git
# ==> Downloading and installing Homebrew...
# ==> Updating Homebrew...
# Warning: /home/linuxbrew/.linuxbrew/bin is not in your PATH.
#   Instructions on how to configure your shell for Homebrew
#   can be found in the 'Next steps' section below.
# ==> Installation successful!
#
# ==> Homebrew has enabled anonymous aggregate formulae and cask analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics data has been sent yet (nor will any be during this install run).
#
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Next steps:
# - Run these commands in your terminal to add Homebrew to your PATH:
#     echo >> /teamspace/studios/this_studio/.profile
#     echo 'eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv)"' >> /teamspace/studios/this_studio/.profile
#     eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv)"
# - Install Homebrew's dependencies if you have sudo access:
#     sudo apt-get install build-essential
#   For more information, see:
#     https://docs.brew.sh/Homebrew-on-Linux
# - We recommend that you install GCC:
#     brew install gcc
# - Run brew help to get started
# - Further documentation:
#     https://docs.brew.sh

# %%
# add homebrew to path and apply it to the current session
# For Linux
# !echo 'eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv)"'  >> ~/.bashrc
# !eval "$(/home/linuxbrew/.linuxbrew/bin/brew shellenv)"

# For macOS M1/M2/M3 
# echo 'eval "$(/opt/homebrew/bin/brew shellenv)"' >> ~/.zprofile 
# eval "$(/opt/homebrew/bin/brew shellenv)"

# For masOS (Intel)
# echo 'eval "$(/usr/local/bin/brew shellenv)"'  >> ~/.zprofile
# eval "$(/usr/local/bin/brew shellenv)"

# %%
# install homebrew dependencies
# For Debian or Ubuntu
# !sudo apt-get install build-essential procps curl file git

# For Fedora
# sudo dnf group install development-tools
# sudo dnf install procps-ng curl file

# For CentOS Stream or RHEL
# sudo dnf group install 'Development Tools'
# sudo dnf install procps-ng curl file

# For Arch Linux
# sudo pacman -S base-devel procps-ng curl file git

# %% [markdown]
# ### Installing Docker on Ubuntu Linux

# %%
# uninstall old docker version if it already exists on machine.
# !sudo apt remove docker docker-engine docker.io containerd runc docker-compose docker-compose-v2 docker-doc podman-docker
# Out:
# Reading package lists... 0%
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'docker' is not installed, so not removed
# Package 'docker-engine' is not installed, so not removed
# Package 'docker.io' is not installed, so not removed
# Package 'containerd' is not installed, so not removed
# Package 'runc' is not installed, so not removed
# Package 'docker-compose' is not installed, so not removed
# Package 'docker-compose-v2' is not installed, so not removed
# Package 'docker-doc' is not installed, so not removed
# Package 'podman-docker' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %%
# Update package index, install prerequisites and add Docker's official GPG key:
# !sudo apt update
# !sudo apt install ca-certificates curl
# !sudo install -m 0755 -d /etc/apt/keyrings
# !sudo curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc
# !sudo chmod a+r /etc/apt/keyrings/docker.asc
# Out:
# Get:1 https://download.docker.com/linux/ubuntu noble InRelease [48.5 kB]
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [1620 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1923 kB]0m
# Get:5 https://download.docker.com/linux/ubuntu noble/stable amd64 Packages [51.8 kB]
# Get:6 https://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:7 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [4451 kB]
# Hit:8 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
# Get:9 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]3m
# Get:10 https://archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:11 http://deb.wakemeops.com/wakemeops stable InRelease [50.5 kB]
# Get:12 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:13 https://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [1776 kB]3m
# Get:14 https://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:15 https://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:16 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2171 kB]
# Get:17 https://security.ubuntu.com/ubuntu noble-security amd64 Contents (deb) [119 MB]3m
# Get:18 https://cloud.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:19 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates amd64 Contents (deb) [128 MB]
# Get:20 https://archive.ubuntu.com/ubuntu noble/main amd64 Packages [1808 kB]
# Get:21 https://archive.ubuntu.com/ubuntu noble amd64 Contents (deb) [51.3 MB]
# Get:22 https://cloud.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:23 http://deb.wakemeops.com/wakemeops stable/dev amd64 Packages [161 kB]
# Get:24 https://cloud.archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]0m
# Get:25 https://archive.ubuntu.com/ubuntu noble/universe amd64 Packages [19.3 MB]
# Get:26 http://deb.wakemeops.com/wakemeops stable/devops amd64 Packages [434 kB]
# Get:27 https://cloud.archive.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:28 http://deb.wakemeops.com/wakemeops stable/secops amd64 Packages [85.9 kB]
# Get:29 http://deb.wakemeops.com/wakemeops stable/terminal amd64 Packages [114 kB]0m
# Get:30 https://archive.ubuntu.com/ubuntu noble/restricted amd64 Packages [117 kB]0m
# Get:31 http://deb.wakemeops.com/wakemeops stable/desktop amd64 Packages [21.1 kB]
# Get:32 https://cloud.archive.ubuntu.com/ubuntu noble/main amd64 Packages [1808 kB]m
# Get:33 https://archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [331 kB]0m
# Get:34 https://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2171 kB]
# Get:35 https://archive.ubuntu.com/ubuntu noble-updates amd64 Contents (deb) [128 MB]
# Get:36 https://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1194 kB]33m
# Get:37 https://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [3008 kB]
# Get:38 https://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [34.8 kB]
# Get:39 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1975 kB]
# Get:40 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [3219 kB]
# Get:41 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [38.1 kB]
# Get:42 https://cloud.archive.ubuntu.com/ubuntu noble amd64 Contents (deb) [51.3 MB]
# Get:43 https://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1975 kB]
# Get:44 https://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [3219 kB]
# Get:45 https://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [38.1 kB]
# Get:46 https://archive.ubuntu.com/ubuntu noble-backports/main amd64 Packages [49.5 kB]3m
# Get:47 https://archive.ubuntu.com/ubuntu noble-backports amd64 Contents (deb) [782 kB]3m
# Get:48 https://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [34.6 kB]
# Get:49 https://cloud.archive.ubuntu.com/ubuntu noble/universe amd64 Packages [19.3 MB]3m
# Get:50 https://cloud.archive.ubuntu.com/ubuntu noble/restricted amd64 Packages [117 kB]
# Get:51 https://cloud.archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [331 kB]
# Get:52 https://cloud.archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2171 kB]
# Get:53 https://cloud.archive.ubuntu.com/ubuntu noble-updates amd64 Contents (deb) [128 MB]
# Get:54 https://cloud.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1975 kB]m
# Get:55 https://cloud.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [3219 kB]
# Get:56 https://cloud.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [38.1 kB]
# Get:57 https://cloud.archive.ubuntu.com/ubuntu noble-backports/main amd64 Packages [49.5 kB]
# Get:58 https://cloud.archive.ubuntu.com/ubuntu noble-backports amd64 Contents (deb) [782 kB]
# Get:59 https://cloud.archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [34.6 kB]
# Get:60 https://cloud.archive.ubuntu.com/ubuntu noble-security/main amd64 Packages [1776 kB]
# Get:61 https://cloud.archive.ubuntu.com/ubuntu noble-security amd64 Contents (deb) [119 MB]
# Get:62 https://cloud.archive.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1194 kB]
# Get:63 https://cloud.archive.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [3008 kB]
# Get:64 https://cloud.archive.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [34.8 kB]
# Fetched 811 MB in 1min 12s (11.3 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 29 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203).
# curl is already the newest version (8.5.0-2ubuntu10.6).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# Add the docker repository to Apt sources:
# !echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
  $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
  sudo tee /etc/apt/sources.list.d/docker.list > /dev/null

# %%
# Update apt package index, install Docker Engine, CLI, and plugins
# !sudo apt update
# !sudo apt install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin
# Out:
# Hit:1 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://download.docker.com/linux/ubuntu noble InRelease
# Hit:4 https://archive.ubuntu.com/ubuntu noble InRelease
# Hit:5 https://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:6 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
# Hit:7 https://archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:8 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:9 http://deb.wakemeops.com/wakemeops stable InRelease
# Hit:10 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:11 https://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:12 https://cloud.archive.ubuntu.com/ubuntu noble InRelease
# Hit:13 https://cloud.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:14 https://cloud.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:15 https://cloud.archive.ubuntu.com/ubuntu noble-security InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 29 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# containerd.io is already the newest version (2.2.1-1~ubuntu.24.04~noble).
# docker-compose-plugin is already the newest version (5.0.2-1~ubuntu.24.04~noble).
# The following additional packages will be installed:
#   docker-ce-rootless-extras
# Suggested packages:
#   cgroupfs-mount | cgroup-lite docker-model-plugin
# The following packages will be upgraded:
#   docker-buildx-plugin docker-ce docker-ce-cli docker-ce-rootless-extras
# 4 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Need to get 65.4 MB of archives.
# After this operation, 40.6 MB of additional disk space will be used.
# Get:1 https://download.docker.com/linux/ubuntu noble/stable amd64 docker-ce-cli amd64 5:29.2.0-1~ubuntu.24.04~noble [16.3 MB]
# Get:2 https://download.docker.com/linux/ubuntu noble/stable amd64 docker-ce amd64 5:29.2.0-1~ubuntu.24.04~noble [22.5 MB]
# Get:3 https://download.docker.com/linux/ubuntu noble/stable amd64 docker-buildx-plugin amd64 0.31.1-1~ubuntu.24.04~noble [20.3 MB]
# Get:4 https://download.docker.com/linux/ubuntu noble/stable amd64 docker-ce-rootless-extras amd64 5:29.2.0-1~ubuntu.24.04~noble [6387 kB]
# Fetched 65.4 MB in 1s (92.9 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# (Reading database ... 142871 files and directories currently installed.)
# Preparing to unpack .../docker-ce-cli_5%3a29.2.0-1~ubuntu.24.04~noble_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking docker-ce-cli (5:29.2.0-1~ubuntu.24.04~noble) over (5:28.0.1-1~ubuntu.24.04~noble) ...
# 7Progress: [ 12%] [######....................................................] 8Preparing to unpack .../docker-ce_5%3a29.2.0-1~ubuntu.24.04~noble_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking docker-ce (5:29.2.0-1~ubuntu.24.04~noble) over (5:28.0.1-1~ubuntu.24.04~noble) ...
# 7Progress: [ 24%] [#############.............................................] 8Preparing to unpack .../docker-buildx-plugin_0.31.1-1~ubuntu.24.04~noble_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking docker-buildx-plugin (0.31.1-1~ubuntu.24.04~noble) over (0.30.1-1~ubuntu.24.04~noble) ...
# 7Progress: [ 35%] [####################......................................] 8Preparing to unpack .../docker-ce-rootless-extras_5%3a29.2.0-1~ubuntu.24.04~noble_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking docker-ce-rootless-extras (5:29.2.0-1~ubuntu.24.04~noble) over (5:28.0.1-1~ubuntu.24.04~noble) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up docker-buildx-plugin (0.31.1-1~ubuntu.24.04~noble) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up docker-ce-cli (5:29.2.0-1~ubuntu.24.04~noble) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up docker-ce-rootless-extras (5:29.2.0-1~ubuntu.24.04~noble) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up docker-ce (5:29.2.0-1~ubuntu.24.04~noble) ...
# 7Progress: [ 88%] [###################################################.......] 8invoke-rc.d: policy-rc.d denied execution of restart.
# /usr/sbin/policy-rc.d returned 101, not running 'restart docker.service docker.socket'
# 7Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.12.0-4build2) ...
#
# 78

# %%
# verify the installation was successful
# !sudo docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
#
# Digest: sha256:05813aedc15fb7b4d732e1be879d3252c1c9c25d885824f6295cab4538cb85cd
# Status: Downloaded newer image for hello-world:latest
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Installing Docker Model Runner

# %%
# Docker Model Runner is available as a package. To install it, run
# !sudo apt-get update
# !sudo apt-get install docker-model-plugin

# check installation success
# !docker model version
# Out:
# Hit:1 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://download.docker.com/linux/ubuntu noble InRelease
# 0% [Connecting to cloud.archive.ubuntu.com (91.189.91.93)] [Connected to us-eas
# Hit:4 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
# Hit:5 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:6 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:7 http://deb.wakemeops.com/wakemeops stable InRelease
# Hit:8 https://archive.ubuntu.com/ubuntu noble InRelease
# Hit:9 https://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:10 https://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:11 https://archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:12 https://cloud.archive.ubuntu.com/ubuntu noble InRelease
# Hit:13 https://cloud.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:14 https://cloud.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:15 https://cloud.archive.ubuntu.com/ubuntu noble-security InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   docker-model-plugin
# 0 upgraded, 1 newly installed, 0 to remove and 25 not upgraded.
# Need to get 7235 kB of archives.
# After this operation, 27.8 MB of additional disk space will be used.
# Get:1 https://download.docker.com/linux/ubuntu noble/stable amd64 docker-model-plugin amd64 1.0.9-1~ubuntu.24.04~noble [7235 kB]
# Fetched 7235 kB in 0s (16.9 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package docker-model-plugin.
# (Reading database ... 142862 files and directories currently installed.)
# Preparing to unpack .../docker-model-plugin_1.0.9-1~ubuntu.24.04~noble_amd64.deb ...
# Unpacking docker-model-plugin (1.0.9-1~ubuntu.24.04~noble) ...
# Setting up docker-model-plugin (1.0.9-1~ubuntu.24.04~noble) ...
# Docker Model Runner version v1.0.9
# Docker Engine Kind: Docker Engine

# %% [markdown]
# ### Install KitOps CLI

# %%
# !brew tap kitops-ml/kitops
# !brew install kitops

# check installation
# !kit version
# Out:
# ⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠙ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠙ JSON API cask.jws.json                             Downloading  15.3MB/-------⠙ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠙ JSON API cask.jws.json                             Downloading 393.2KB/-------⠚ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠚ JSON API cask.jws.json                             Downloading  15.3MB/-------⠚ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠞ JSON API cask.jws.json                             Downloaded   15.3MB/-------✔︎ JSON API formula.jws.json                          Downloaded   32.0MB/ 32.0MB
# ✔︎ JSON API cask.jws.json                             Downloaded   15.3MB/ 15.3MB
# Warning: kitops-ml/kitops/kitops 1.10.0 is already installed and up-to-date.
# To reinstall 1.10.0, run:
#   brew reinstall kitops
# Version: 1.10.0
# Commit: b27d690ac61d5a1e5dd40bc7555f1adc3b75fa63
# Built: 2025-11-07T18:58:26Z
# Go version: go1.24.0

# %% [markdown]
# ### Installing Minikube & kubectl
# we require Minikube to setup a kubernetes cluster locally on our machine, and kubectl is a command-line tool we will use to communicate with Minikube

# %%
# Note kubectl will be automatically installed with minikube.
# !brew install minikube
# Out:
# Warning: minikube 1.38.0 is already installed and up-to-date.
# To reinstall 1.38.0, run:
#   brew reinstall minikube

# %%
# start minikube's kubernetes cluster locally.
# !minikube start
# Out:
# 😄  minikube v1.38.0 on Ubuntu 24.04 (docker/amd64)
# ✨  Using the docker driver based on existing profile
# 👍  Starting "minikube" primary control-plane node in "minikube" cluster
# 🚜  Pulling base image v0.0.49 ...
# 🔄  Restarting existing docker container for "minikube" ...-
# 🔄  Restarting existing docker container for "minikube" ...7m/
# 🐳  Preparing Kubernetes v1.35.0 on Docker 29.2.0 ...7m\
# 🔎  Verifying Kubernetes components...
#     ▪ Using image gcr.io/k8s-minikube/storage-provisioner:v5
# 🌟  Enabled addons: default-storageclass, storage-provisioner
# 🏄  Done! kubectl is now configured to use "minikube" cluster and "default" namespace by default

# %% [markdown]
# ### Install the required Python libraries

# %%
# we assume you have python already installed
# !pip install openai kitops
# Out:
# Collecting openai
#   Downloading openai-2.16.0-py3-none-any.whl.metadata (29 kB)
# Collecting kitops
#   Downloading kitops-1.4.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from openai) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from openai) (2.12.5)
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: python-dotenv<2.0,>=1.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kitops) (1.2.1)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kitops) (6.0.3)
# Downloading openai-2.16.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.9 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (361 kB)
# Downloading kitops-1.4.0-py3-none-any.whl (25 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, jiter, distro, openai, kitops
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [kitops]2m3/5 [openai]
# Successfully installed distro-1.9.0 jiter-0.12.0 kitops-1.4.0 openai-2.16.0 sniffio-1.3.1

# %% [markdown]
# ### Authenticate KitOps CLI with Jozu Hub

# %%
# Run the below command in the terminal, you will be prompted to insert the username (email) and password, 
# you used to create the jozu hub account. 
# Note: As you are typing the password it won't show on most terminals so don't be surprised 
# just hit enter when you are done.


# kit login jozu.ml

# %% [markdown]
# ### Pulling & Extracting the Model from Docker

# %%
# pulling the model
# !docker model pull ai/smollm2
# Out:
# latest: Pulling from docker/model-runner
#
# 408d7713: Pulling fs layer
# 61b56cf4: Pulling fs layer
# 5e81f27e: Pulling fs layer
# 5952b45f: Pulling fs layer
# 12754a26: Pulling fs layer
# 4ee68446: Pulling fs layer
# c5dd5c4b: Pulling fs layer
# feaee46b: Pulling fs layer
# Digest: sha256:795efebeaf009009ccc9d4ee5671969fed8de46559062f6816ed53e0efe3b6bf
# Status: Downloaded newer image for docker/model-runner:latest
# Successfully pulled docker/model-runner:latest
# Creating model storage volume docker-model-runner-models...
# Starting model runner container docker-model-runner...
#
# 749b96f6: Pull complete  11.36kB/11.36kB
# Model pulled successfully270.6MB/270.6MB2A

# %%
# Make sure to run the model so it is loaded into memory where we can see it to extract.
# docker model run ai/smollm2

# %%
# To extract the model gguf file, first obtain the Container ID of the model runner
# docker ps

# %%
# Next, we will inspect the smollm2 Docker model to obtain its ID. This is so after extraction, 
# we know what folder (it is named after the ID) has our model’s gguf file inside:

# !docker model inspect ai/smollm2
# Out:
# {
#     "id": "sha256:354bf30d0aa3af413d2aa5ae4f23c66d78980072d1e07a5b0d776e9606a2f0b9",
#     "tags": [
#         "docker.io/ai/smollm2:latest"
#     ],
#     "created": 1742816981,
#     "config": {
#         "format": "gguf",
#         "quantization": "IQ2_XXS/Q4_K_M",
#         "parameters": "361.82 M",
#         "architecture": "llama",
#         "size": "256.35 MiB"
#     }
# }

# %%
# Extract the folders with the model gguf file to your local machine.

# Note: This internal container path (/models/bundles/sha256) is implementation-specific. 
# The command below was verified with Docker Engine 27.2.0 and Docker Model Runner v1.0.9. 
# It may change in future releases.

# docker cp <put-docker-model-runner-container-id-here>:/models/bundles/sha256 ./all_models
# Out:
# Successfully copied 271MB to /teamspace/studios/this_studio/mlops/all_models

# %% [markdown]
# ### Packaging & versioning the model’s gguf file as a ModelKit

# %%
from kitops.modelkit.kitfile import Kitfile

# Create new Kitfile
kitfile = Kitfile()

# Set basic metadata
kitfile.manifestVersion = "1.0"
kitfile.package = {
    "name": "smollm2",
    "version": "1.0",
    "description": "Sample kitfile for Smollm2"
}

# Configure model information
kitfile.model = {
    "name": "smollm2",
    "path": "all_models/smollm2/model/model.gguf",
    "version": "1.0",
    "license": "Apache 2.0",
    "description": "GGUF file for smollm2"
}

# Add code files
kitfile.code = [
    {
        "path": "all_models/smollm2/config.json",
        "description": "config json file of smollm2"
    }
]


# You can also add other information like below:

# kitfile.datasets = [
#     {
#         "name": "dataset",
#         "path": "data/sample.csv",
#         "description": "full dataset",
#         "license": "Apache 2.0"
#     }
# ]

# kitfile.docs = [
#     {"path": "docs/README.md"},
#     {"path": "docs/LICENSE"}
# ]

# For more information on what you can add, see https://kitops.org/docs/pykitops/how-to-guides/


# Save the Kitfile locally (Note: It is the Kitfile that specifies how the Modelkit will be bundled)
kitfile.save("./Smollm2-Kitfile")
# Out:
# Kitfile Contents...
# ===================
#
# manifestVersion: '1.0'
# package:
#   name: smollm2
#   version: '1.0'
#   description: Sample kitfile for Smollm2
# code:
# - path: all_models/smollm2/config.json
#   description: config json file of smollm2
# datasets: []
# docs: []
# model:
#   path: all_models/smollm2/model/model.gguf
#   name: smollm2
#   version: '1.0'
#   description: GGUF file for smollm2
#   license: Apache 2.0
# /tmp/ipykernel_194114/3061279848.py:52: DeprecationWarning: print argument is going to be deprecated. To print Kitfile use to_yaml() and your favorite way to log/print; date=2025-02-21
#   kitfile.save("./Smollm2-Kitfile")

# %%
from kitops.modelkit.manager import ModelKitManager, UserCredentials

# Configure the ModelKit manager
# Note: The email prefix of jack123@gmail.com is just jack123

modelkit_tag = "jozu.ml/email-prefix-here/repo-name-here:latest" # all in lowercase
manager = ModelKitManager(
    working_directory=".",
    modelkit_tag=modelkit_tag,
    user_credentials=UserCredentials('full-email-here', 'password-here', namespace='repo-name-here')
)

# Assign your Kitfile
manager.kitfile = kitfile

# Pack and push to Jozu Hub
manager.pack_and_push_modelkit(save_kitfile=True)

# %% [markdown]
# ### Deploy to Kubernetes Locally on MiniKube

# %%
# Create our pod from what was defined in the file.
# kubectl apply -f jozu-deploy.yaml

# %%
# Check logs to ensure it our pod is running.
# !kubectl logs smollm2-llama-cpp
# Out:
# Found gguf: '/all_models/smollm2/model/model.gguf'
# load_backend: loaded CPU backend from /app/libggml-cpu-haswell.so
# warn: LLAMA_ARG_HOST environment variable is set, but will be overwritten by command line argument --host
# build: 5124 (bc091a4d) with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# system info: n_threads = 2, n_threads_batch = 2, total_threads = 4
#
# system_info: n_threads = 2 (n_threads_batch = 2) / 4 | CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | BMI2 = 1 | LLAMAFILE = 1 | OPENMP = 1 | AARCH64_REPACK = 1 |
#
# main: binding port with default address family
# main: HTTP server is listening, hostname: 0.0.0.0, port: 8000, http threads: 3
# main: loading model
# srv    load_model: loading model '/all_models/smollm2/model/model.gguf'
# llama_model_loader: loaded meta data with 33 key-value pairs and 290 tensors from /all_models/smollm2/model/model.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = SmolLM2 360M Instruct
# llama_model_loader: - kv   3:                           general.finetune str              = Instruct
# llama_model_loader: - kv   4:                           general.basename str              = SmolLM2
# llama_model_loader: - kv   5:                         general.size_label str              = 360M
# llama_model_loader: - kv   6:                            general.license str              = apache-2.0
# llama_model_loader: - kv   7:                               general.tags arr[str,4]       = ["safetensors", "onnx", "transformers...
# llama_model_loader: - kv   8:                          general.languages arr[str,1]       = ["en"]
# llama_model_loader: - kv   9:                          llama.block_count u32              = 32
# llama_model_loader: - kv  10:                       llama.context_length u32              = 8192
# llama_model_loader: - kv  11:                     llama.embedding_length u32              = 960
# llama_model_loader: - kv  12:                  llama.feed_forward_length u32              = 2560
# llama_model_loader: - kv  13:                 llama.attention.head_count u32              = 15
# llama_model_loader: - kv  14:              llama.attention.head_count_kv u32              = 5
# llama_model_loader: - kv  15:                       llama.rope.freq_base f32              = 100000.000000
# llama_model_loader: - kv  16:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  17:                           llama.vocab_size u32              = 49152
# llama_model_loader: - kv  18:                 llama.rope.dimension_count u32              = 64
# llama_model_loader: - kv  19:                       tokenizer.ggml.model str              = gpt2
# llama_model_loader: - kv  20:                         tokenizer.ggml.pre str              = smollm
# llama_model_loader: - kv  21:                      tokenizer.ggml.tokens arr[str,49152]   = ["<|endoftext|>", "<|im_start|>", "<|...
# llama_model_loader: - kv  22:                  tokenizer.ggml.token_type arr[i32,49152]   = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  23:                      tokenizer.ggml.merges arr[str,48900]   = ["Ġ t", "Ġ a", "i n", "h e", "Ġ Ġ...
# llama_model_loader: - kv  24:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  25:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  26:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  27:            tokenizer.ggml.padding_token_id u32              = 2
# llama_model_loader: - kv  28:                    tokenizer.chat_template str              = {% for message in messages %}{% if lo...
# llama_model_loader: - kv  29:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  30:               tokenizer.ggml.add_bos_token bool             = false
# llama_model_loader: - kv  31:               general.quantization_version u32              = 2
# llama_model_loader: - kv  32:                          general.file_type u32              = 15
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q5_0:  176 tensors
# llama_model_loader: - type q8_0:   17 tensors
# llama_model_loader: - type q4_K:   16 tensors
# llama_model_loader: - type q6_K:   16 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 256.35 MiB (5.94 BPW)
# load: special tokens cache size = 17
# load: token to piece cache size = 0.3170 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 8192
# print_info: n_embd           = 960
# print_info: n_layer          = 32
# print_info: n_head           = 15
# print_info: n_head_kv        = 5
# print_info: n_rot            = 64
# print_info: n_swa            = 0
# print_info: n_swa_pattern    = 1
# print_info: n_embd_head_k    = 64
# print_info: n_embd_head_v    = 64
# print_info: n_gqa            = 3
# print_info: n_embd_k_gqa     = 320
# print_info: n_embd_v_gqa     = 320
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 2560
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 100000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 8192
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 3B
# print_info: model params     = 361.82 M
# print_info: general.name     = SmolLM2 360M Instruct
# print_info: vocab type       = BPE
# print_info: n_vocab          = 49152
# print_info: n_merges         = 48900
# print_info: BOS token        = 1 '<|im_start|>'
# print_info: EOS token        = 2 '<|im_end|>'
# print_info: EOT token        = 0 '<|endoftext|>'
# print_info: UNK token        = 0 '<|endoftext|>'
# print_info: PAD token        = 2 '<|im_end|>'
# print_info: LF token         = 198 'Ċ'
# print_info: EOG token        = 0 '<|endoftext|>'
# print_info: EOG token        = 2 '<|im_end|>'
# print_info: max token length = 162
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors:  CPU_AARCH64 model buffer size =    21.09 MiB
# load_tensors:   CPU_Mapped model buffer size =   256.35 MiB
# ...................................................................................
# llama_context: constructing llama_context
# llama_context: n_seq_max     = 1
# llama_context: n_ctx         = 4096
# llama_context: n_ctx_per_seq = 4096
# llama_context: n_batch       = 2048
# llama_context: n_ubatch      = 512
# llama_context: causal_attn   = 1
# llama_context: flash_attn    = 0
# llama_context: freq_base     = 100000.0
# llama_context: freq_scale    = 1
# llama_context: n_ctx_per_seq (4096) < n_ctx_train (8192) -- the full capacity of the model will not be utilized
# llama_context:        CPU  output buffer size =     0.19 MiB
# init: kv_size = 4096, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 32, can_shift = 1
# init:        CPU KV buffer size =   160.00 MiB
# llama_context: KV self size  =  160.00 MiB, K (f16):   80.00 MiB, V (f16):   80.00 MiB
# llama_context:        CPU compute buffer size =   135.51 MiB
# llama_context: graph nodes  = 1094
# llama_context: graph splits = 1
# common_init_from_params: setting dry_penalty_last_n to ctx_size = 4096
# common_init_from_params: warming up the model with an empty run - please wait ... (--no-warmup to disable)
# srv          init: initializing slots, n_slots = 1
# slot         init: id  0 | task -1 | new slot n_ctx_slot = 4096
# main: model loaded
# main: chat template, chat_template: {% for message in messages %}{% if loop.first and messages[0]['role'] != 'system' %}{{ '<|im_start|>system
# You are a helpful AI assistant named SmolLM, trained by Hugging Face<|im_end|>
# ' }}{% endif %}{{'<|im_start|>' + message['role'] + '
# ' + message['content'] + '<|im_end|>' + '
# '}}{% endfor %}{% if add_generation_prompt %}{{ '<|im_start|>assistant
# ' }}{% endif %}, example_format: '<|im_start|>system
# You are a helpful assistant<|im_end|>
# <|im_start|>user
# Hello<|im_end|>
# <|im_start|>assistant
# Hi there<|im_end|>
# <|im_start|>user
# How are you?<|im_end|>
# <|im_start|>assistant
# '
# main: server is listening on http://0.0.0.0:8000 - starting the main loop
# srv  update_slots: all slots are idle

# %%
# Forward the 8000 port so we can communicate with the pod.
# kubectl port-forward pod/smollm2-llama-cpp 8000:8000

# %% [markdown]
# ### Communicating via OpenAI sdk

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8000/",
    api_key="sk-no-key-required"
)

response = client.chat.completions.create(
    model="smollm2",
    messages=[
        {
            "role": "user",
            "content": "write a corporate letter asking for funding for the R&D robotic department.",
        }
    ],
    stream=False,
    temperature=0.8,
    max_tokens=500,
)

print(response.choices[0].message.content)
# Out:
# Dear [Corporate Representative],
#
# We are writing to express our gratitude for the recent invitation to present our research and development (R&D) team at the upcoming National Technology and Innovation Summit (NTIS). As we have been long-time supporters of the R&D department at [Company Name], we believe that our investment in this area will yield significant benefits to both our organization and the broader technological landscape.
#
# Our R&D team has made substantial progress in our current project, [Project Name], which we believe will have a profound impact on [Company Name]'s operations and competitiveness. We are excited about the opportunity to share our findings and insights with the NTIS attendees, and we are confident that our research will contribute meaningfully to the discussions on innovation and business development at the summit.
#
# As we have done many times in the past, we would like to propose a grant of $100,000 to support the development of [Project Name]. This grant will help us fund the necessary infrastructure, research and development, and personnel to ensure the success of the project. We believe that this investment will not only enhance our team's capabilities but also provide a competitive advantage to [Company Name] in the future.
#
# We are excited about this opportunity to collaborate with you and share our knowledge and expertise. We look forward to the prospect of working together and making a lasting impact on our industry.
#
# Sincerely,
#
# [Your Name]
#
# This corporate letter explains the R&D department's research and its significance, highlights the proposed grant, and emphasizes the potential benefits of collaboration.
